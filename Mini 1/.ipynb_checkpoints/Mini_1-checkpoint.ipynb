# %%
import hdbscan
import debacl
import fastcluster
import sklearn.cluster
import scipy.cluster
import gensim
from sklearn.manifold import TSNE
# Out:
# INFO (2018-04-11 04:30:35): 'pattern' package not found; tag filters are not available for English

# %%
import random
import sklearn.datasets
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_context('poster')
sns.set_palette('Paired', 10)
sns.set_color_codes()

# %%
def benchmark_algorithm(dataset, dataset_sizes, cluster_function, function_args, function_kwds):
    
    result = np.nan * np.ones((len(dataset_sizes)))
    labels = {}
    for index, size in enumerate(dataset_sizes):
            
            data = dataset[index]
            # Start the clustering with a timer
            start_time = time.time()
            k = cluster_function(data, *function_args, **function_kwds)
            time_taken = time.time() - start_time
            
            result[index] = time_taken
            try:
                labels[index] = k.labels_
            except:
                labels[index] = k
                
    # Return the result as a dataframe for easier handling with seaborn afterwards
    return result, labels

# %%
def to_df(data, sizes):
    return pd.DataFrame(np.vstack([sizes, data.flatten()]).T, columns=['x','y'])

# %%
def create_word_vec(models, nork='n'):
    word_vecs = [model.wv for model in models]
    if nork=='n':
        data_sizes = [len(word_vect.vocab) for word_vect in word_vecs]
    else:
        data_sizes = [len(word_vect.syn0[0]) for word_vect in word_vecs]
    w2v = [dict(zip(word_vect.index2word,word_vect.syn0)) for 
           word_vect in word_vecs]
    return data_sizes, w2v

# %% [markdown]
# Get data

# %%
text_file_name = 'wikipedia.txt'

# %% [markdown]
# For increasing data size (n)

# %%
data = [gensim.models.word2vec.LineSentence(text_file_name, limit=i) for i in range(100,100000,10000)]

# %%
simple_models = [gensim.models.Word2Vec(i, size=10, window=5,
                                      min_count=5, workers=8) for i in data]
# Out:
# WARNING (2018-04-11 04:32:48): consider setting layer size to a multiple of 4 for greater performance
# INFO (2018-04-11 04:32:48): collecting all words and their counts
# INFO (2018-04-11 04:32:48): PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO (2018-04-11 04:32:48): collected 773 word types from a corpus of 2224 raw words and 100 sentences
# INFO (2018-04-11 04:32:48): Loading a fresh vocabulary
# INFO (2018-04-11 04:32:48): min_count=5 retains 75 unique words (9% of original 773, drops 698)
# INFO (2018-04-11 04:32:48): min_count=5 leaves 1231 word corpus (55% of original 2224, drops 993)
# INFO (2018-04-11 04:32:48): deleting the raw counts dictionary of 773 items
# INFO (2018-04-11 04:32:48): sample=0.001 downsamples 75 most-common words
# INFO (2018-04-11 04:32:48): downsampling leaves estimated 389 word corpus (31.6% of prior 1231)
# INFO (2018-04-11 04:32:48): estimated required memory for 75 words and 10 dimensions: 43500 bytes
# INFO (2018-04-11 04:32:48): resetting layer weights
# INFO (2018-04-11 04:32:48): training model with 8 workers on 75 vocabulary and 10 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# INFO (2018-04-11 04:32:48): worker thread finished; awaiting finish of 7 more threads
# INFO (2018-04-11 04:32:48): worker thread finished; awaiting finish of 6 more threads
# INFO (2018-04-11 04:32:48): worker thread finished; awaiting finish of 5 more threads
# INFO (2018-04-11 04:32:48): worker thread finished; awaiting finish of 4 more threads
# INFO (2018-04-11 04:32:48): worker thread finished; awaiting finish of 3 more threads
# INFO (2018-04-11 04:32:48): worker thread finished; awaiting finish of 2 more threads
# INFO (2018-04-11 04:32:48): worker thread finished; awaiting finish of 1 more threads
# INFO (2018-04-11 04:32:48): worker thread finished; awaiting finish of 0 more threads
# INFO (2018-04-11 04:32:48): training on 11120 raw words (1882 effective words) took 0.0s, 39782 effective words/s
# WARNING (2018-04-11 04:32:48): under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
words/s, in_qsize 15, out_qsize 0
# INFO (2018-04-11 04:33:50): PROGRESS: at 66.38% examples, 639252 words/s, in_qsize 14, out_qsize 3
# INFO (2018-04-11 04:33:51): PROGRESS: at 75.09% examples, 644603 words/s, in_qsize 15, out_qsize 0
# INFO (2018-04-11 04:33:52): PROGRESS: at 84.65% examples, 651804 words/s, in_qsize 15, out_qsize 0
# INFO (2018-04-11 04:33:53): PROGRESS: at 92.69% examples, 649787 words/s, in_qsize 15, out_qsize 0
# INFO (2018-04-11 04:33:54): worker thread finished; awaiting finish of 7 more threads
# INFO (2018-04-11 04:33:54): worker thread finished; awaiting finish of 6 more threads
# INFO (2018-04-11 04:33:54): worker thread finished; awaiting finish of 5 more threads
# INFO (2018-04-11 04:33:54): worker thread finished; awaiting finish of 4 more threads
# INFO (2018-04-11 04:33:54): worker thread finished; awaiting finish of 3 more threads
# INFO (2018-04-11 04:33:54): worker thread finished; awaiting finish of 2 more threads
# INFO (2018-04-11 04:33:54): worker thread finished; awaiting finish of 1 more threads
# INFO (2018-04-11 04:33:54): worker thread finished; awaiting finish of 0 more threads
# INFO (2018-04-11 04:33:54): training on 11478630 raw words (7788008 effective words) took 11.9s, 654537 effective words/s

# %%
n_sizes, w2v_large_n = create_word_vec(simple_models, 'n')

# %%
np.array(n_sizes)[0,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-fccc99c063c3> in <module>()
# ----> 1 np.array(n_sizes)[0,1]
#
# IndexError: too many indices for array

# %%
def plot_TSNE(data, labels):
    digits_proj = TSNE(random_state=1).fit_transform(list(data.values()))
    plt.figure(figsize=(25,10))
    plt.xlabel('Component #1')
    plt.ylabel('Component #2')
    indices = random.sample([i for i in range(len(digits_proj[:,0]))],100)
    for label, x, y in np.array(list(zip(list(data.keys()), digits_proj[:,0], digits_proj[:,1])))[indices]:
            plt.annotate(label, xy=(x, y), xytext=(0, 0), size='small', textcoords='offset points')
    plt.scatter(digits_proj[:,0], digits_proj[:,1], c=labels)
    #plt.savefig('Kmeans.png')

# %%
w2v_large_n_vecs = [list(w.values()) for w in w2v_large_n]

# %%
k_means = sklearn.cluster.KMeans(10)
k_means_data, k_labels = benchmark_algorithm(w2v_large_n_vecs, n_sizes, k_means.fit, (), {})

dbscan = sklearn.cluster.DBSCAN(eps=0.2)
dbscan_data, db_labels = benchmark_algorithm(w2v_large_n_vecs, n_sizes, dbscan.fit, (), {})

scipy_single_data, h_labels = benchmark_algorithm(w2v_large_n_vecs, n_sizes,
                                        scipy.cluster.hierarchy.complete, (), {})

# %%
plot_TSNE(w2v_large_n[1], k_labels[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     235
#     236     if 'png' in formats:
# --> 237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
#     239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     119
#     120     bytes_io = BytesIO()
# --> 121     fig.canvas.print_figure(bytes_io, **kw)
#     122     data = bytes_io.getvalue()
#     123     if fmt == 'svg':
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2206                     orientation=orientation,
#    2207                     dryrun=True,
# -> 2208                     **kwargs)
#    2209                 renderer = self.figure._cachedRenderer
#    2210                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             if toolbar:
#     429                 toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             if toolbar:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1293
#    1294             mimage._draw_list_compositing_images(
# -> 1295                 renderer, self, artists, self.suppressComposite)
#    1296
#    1297             renderer.close_group('figure')
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2397             renderer.stop_rasterizing()
#    2398
# -> 2399         mimage._draw_list_compositing_images(renderer, self, artists)
#    2400
#    2401         renderer.close_group('axes')
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/text.py in draw(self, renderer)
#    2330             return
#    2331
# -> 2332         xy_pixel = self._get_position_xy(renderer)
#    2333         if not self._check_xy(renderer, xy_pixel):
#    2334             return
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/text.py in _get_position_xy(self, renderer)
#    1919         "Return the pixel position of the annotated point."
#    1920         x, y = self.xy
# -> 1921         return self._get_xy(renderer, x, y, self.xycoords)
#    1922
#    1923     def _check_xy(self, renderer, xy_pixel):
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/text.py in _get_xy(self, renderer, x, y, s)
#    1771
#    1772         if s1 == 'data':
# -> 1773             x = float(self.convert_xunits(x))
#    1774         if s2 == 'data':
#    1775             y = float(self.convert_yunits(y))
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     189         if ax is None or ax.xaxis is None:
#     190             return x
# --> 191         return ax.xaxis.convert_units(x)
#     192
#     193     def convert_yunits(self, y):
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1489             return x
#    1490
# -> 1491         ret = self.converter.convert(x, self.units, self)
#    1492         return ret
#    1493
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      41         data as floats
#      42         """
# ---> 43         vmap = dict(zip(axis.unit_data.seq, axis.unit_data.locs))
#      44
#      45         if isinstance(value, six.string_types):
#
# AttributeError: 'NoneType' object has no attribute 'seq'

# %%
from scipy.cluster.hierarchy import dendrogram

# %%
plt.figure(figsize=(25,10))
dendrogram(h_labels[0], labels=list(w2v_large_n[0].keys()), leaf_rotation=90., leaf_font_size=8.,)
plt.show()

# %%
fastclust_data = benchmark_algorithm(w2v_large_n_vecs, n_sizes,
                                     fastcluster.linkage_vector, (), {})

agglomerative = sklearn.cluster.AgglomerativeClustering(10)
agg_data = benchmark_algorithm(w2v_large_n_vecs, n_sizes,
                               agglomerative.fit, (), {})

spectral = sklearn.cluster.SpectralClustering(10)
spectral_data = benchmark_algorithm(w2v_large_n_vecs, n_sizes,
                                    spectral.fit, (), {})

affinity_prop = sklearn.cluster.AffinityPropagation()
ap_data = benchmark_algorithm(w2v_large_n_vecs, n_sizes,
                              affinity_prop.fit, (), {})
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/sparse/csgraph/_laplacian.py:72: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if normed and (np.issubdtype(csgraph.dtype, int)

# %%
plt.figure(figsize=(25,10))
sns.regplot(x='x', y='y', data=to_df(k_means_data, n_sizes), order=2,
            label='Sklearn K-Means', x_estimator=np.mean)
sns.regplot(x='x', y='y', data=to_df(dbscan_data, n_sizes), order=2,
            label='Sklearn DBSCAN', x_estimator=np.mean)
sns.regplot(x='x', y='y', data=to_df(scipy_single_data, n_sizes), order=2,
            label='Scipy Single Linkage', x_estimator=np.mean)

plt.gca().axis([0, 25000, 0, 100])
plt.gca().set_xlabel('Number of data points')
plt.gca().set_ylabel('Time taken to cluster (s)')
plt.title('Performance Comparison of Clustering Implementations')
plt.legend()
plt.savefig('large_n_plot.png')

# %% [markdown]
# For high dimensionality (large k)

# %%
data_dim = data[1]

# %%
dim_models = [gensim.models.Word2Vec(data_dim, size=i, window=5,
                                      min_count=5, workers=16) for i in range(5000,50000,5000)]
# Out:
# INFO (2018-04-11 05:36:43): collecting all words and their counts
# INFO (2018-04-11 05:36:43): PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO (2018-04-11 05:36:43): PROGRESS: at sentence #10000, processed 247383 words, keeping 23992 word types
# INFO (2018-04-11 05:36:43): collected 24158 word types from a corpus of 249357 raw words and 10100 sentences
# INFO (2018-04-11 05:36:43): Loading a fresh vocabulary
# INFO (2018-04-11 05:36:43): min_count=5 retains 5281 unique words (21% of original 24158, drops 18877)
# INFO (2018-04-11 05:36:43): min_count=5 leaves 220094 word corpus (88% of original 249357, drops 29263)
# INFO (2018-04-11 05:36:43): deleting the raw counts dictionary of 24158 items
# INFO (2018-04-11 05:36:43): sample=0.001 downsamples 36 most-common words
# INFO (2018-04-11 05:36:43): downsampling leaves estimated 151390 word corpus (68.8% of prior 220094)
# INFO (2018-04-11 05:36:43): estimated required memory for 5281 words and 5000 dimensions: 213880500 bytes
# INFO (2018-04-11 05:36:43): resetting layer weights
# INFO (2018-04-11 05:36:44): training model with 16 workers on 5281 vocabulary and 5000 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# INFO (2018-04-11 05:36:47): PROGRESS: at 0.85% examples, 2754 words/s, in_qsize 20, out_qsize 0
# INFO (2018-04-11 05:36:48): PROGRESS: at 13.52% examples, 28420 words/s, in_qsize 31, out_qsize 0
# INFO (2018-04-11 05:36:49): PROGRESS: at 19.23% examples, 31098 words/s, in_qsize 31, out_qsize 0
# INFO (2018-04-11 05:36:50): PROGRESS: at 26.38% examples, 33292 words/s, in_qsize 32, out_qsize 0
# INFO (2018-04-11 05:36:52): PROGRESS: at 32.68% examples, 34975 words/s, in_qsize 31, out_qsize 0
# INFO (2018-04-11 05:36:53): PROGRESS: at 40.00% examples, 35239 words/s, in_qsize 31, out_qsize 0
# INFO (2018-04-11 05:36:54): PROGRESS: at 46.38% examples, 35011 words/s, in_qsize 28, out_qsize 3
# INFO (2018-04-11 05:36:56): PROGRESS: at 57.62% examples, 37395 words/s, in_qsize 31, out_qsize 0
# INFO (2018-04-11 05:36:57): PROGRESS: at 66.39% examples, 39543 words/s, in_qsize 31, out_qsize 0
# INFO (2018-04-11 05:36:58): PROGRESS: at 70.41% examples, 38641 words/s, in_qsize 31, out_qsize 0
# INFO (2018-04-11 05:36:59): PROGRESS: at 79.29% examples, 39945 words/s, in_qsize 26, out_qsize 0
# INFO (2018-04-11 05:37:01): PROGRESS: at 83.12% examples, 37693 words/s, in_qsize 21, out_qsize 0
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 15 more threads
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 14 more threads
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 13 more threads
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 12 more threads
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 11 more threads
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 10 more threads
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 9 more threads
# INFO (2018-04-11 05:37:02): PROGRESS: at 93.54% examples, 39737 words/s, in_qsize 8, out_qsize 1
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 8 more threads
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 7 more threads
# INFO (2018-04-11 05:37:02): worker thread finished; awaiting finish of 6 more threads
# INFO (2018-04-11 05:37:03): worker thread finished; awaiting finish of 5 more threads
# INFO (2018-04-11 05:37:03): worker thread finished; awaiting finish of 4 more threads
# INFO (2018-04-11 05:37:03): worker thread finished; awaiting finish of 3 more threads
# INFO (2018-04-11 05:37:03): worker thread finished; awaiting finish of 2 more threads
# INFO (2018-04-11 05:37:03): worker thread finished; awaiting finish of 1 more threads
# INFO (2018-04-11 05:37:03): worker thread finished; awaiting finish of 0 more threads
# INFO (2018-04-11 05:37:03): training on 1246785 raw words (757194 effective words) took 18.4s, 41052 effective words/s
# WARNING (2018-04-11 05:37:03): under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# INFO (2018-04-11 05:37:03): collecting all words and their counts
# INFO (2018-04-11 05:37:03): PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO (2018-04-11 05:37:03): PROGRESS: at sentence #10000, processed 247383 words, keeping 23992 word types
# INFO (2018-04-11 05:37:03): collected 24158 word types from a corpus of 249357 raw words and 10100 sentences
# INFO (2018-04-11 05:37:03): Loading a fresh vocabulary
# INFO (2018-04-11 05:37:03): min_count=5 retains 5281 unique words (21% of original 24158, drops 18877)
# INFO (2018-04-11 05:37:03): min_count=5 leaves 220094 word corpus (88% of original 249357, drops 29263)
# INFO (2018-04-11 05:37:03): deleting the raw counts dictionary of 24158 items
# INFO (2018-04-11 05:37:03): sample=0.001 downsamples 36 most-common words
# INFO (2018-04-11 05:37:03): downsampling leaves estimated 151390 word corpus (68.8% of prior 220094)
# INFO (2018-04-11 05:37:03): estimated required memory for 5281 words and 10000 dimensions: 425120500 bytes
# INFO (2018-04-11 05:37:03): resetting layer weights
# INFO (2018-04-11 05:37:05): training model with 16 workers on 5281 vocabulary and 10000 features, using sg=0 hs=0 sample=0.001 negative=5 window=5

# %%
k_sizes, w2v_large_k = create_word_vec(dim_models, 'k')

# %%
w2v_large_k_vecs = [list(w.values()) for w in w2v_large_k]

# %%
k_means_dim = sklearn.cluster.KMeans(10)
k_means_dimdata, k_dimlabels = benchmark_algorithm(w2v_large_k_vecs, k_sizes, k_means_dim.fit, (), {})

dbscan_dim = sklearn.cluster.DBSCAN(eps=0.2)
dbscan_dimdata, db_dimlabels = benchmark_algorithm(w2v_large_k_vecs, k_sizes, dbscan_dim.fit, (), {})

scipy_single_dimdata, h_dimlabels = benchmark_algorithm(w2v_large_k_vecs, k_sizes,
                                        scipy.cluster.hierarchy.complete, (), {})

# %%
plot_TSNE(w2v_large_k[3],k_dimlabels[3] )

# %%
to_df(k_means_dimdata, k_sizes)
# Out:
#           x         y
# 0     100.0  0.096920
# 1    1100.0  0.133006
# 2    2100.0  0.200475
# 3    3100.0  0.269721
# 4    4100.0  0.468760
# 5    5100.0  0.388599
# 6    6100.0  0.520024
# 7    7100.0  0.631449
# 8    8100.0  0.541599
# 9    9100.0  0.599716
# 10  10100.0  0.793663
# 11  11100.0  0.726246
# 12  12100.0  0.921733
# 13  13100.0  0.840317
# 14  14100.0  1.202728
# 15  15100.0  1.112248
# 16  16100.0  0.976017
# 17  17100.0  1.209175
# 18  18100.0  1.258204
# 19  19100.0  1.361555
# 20  20100.0  1.293352
# 21  21100.0  1.502774
# 22  22100.0  1.553789
# 23  23100.0  1.673153
# 24  24100.0  1.712538
# 25  25100.0  1.776662
# 26  26100.0  1.816670
# 27  27100.0  1.855692
# 28  28100.0  2.087973
# 29  29100.0  1.948707
# 30  30100.0  2.051356
# 31  31100.0  2.138894
# 32  32100.0  2.312316
# 33  33100.0  2.235117
# 34  34100.0  2.500119
# 35  35100.0  2.381360
# 36  36100.0  2.526204
# 37  37100.0  2.453968
# 38  38100.0  2.668117
# 39  39100.0  2.579778
# 40  40100.0  2.806567
# 41  41100.0  2.624308
# 42  42100.0  2.847744
# 43  43100.0  2.925118
# 44  44100.0  2.999608
# 45  45100.0  2.883911
# 46  46100.0  3.092669
# 47  47100.0  3.157325
# 48  48100.0  3.223748
# 49  49100.0  3.380772

# %%
plt.figure(figsize=(25,10))
sns.regplot(x='x', y='y', data=to_df(k_means_dimdata, k_sizes), order=2,
            label='Sklearn K-Means', x_estimator=np.mean)
sns.regplot(x='x', y='y', data=to_df(dbscan_dimdata, k_sizes), order=2,
            label='Sklearn DBSCAN', x_estimator=np.mean)
sns.regplot(x='x', y='y', data=to_df(scipy_single_dimdata, k_sizes), order=2,
            label='Scipy Complete Linkage', x_estimator=np.mean)

plt.gca().axis([0, 50000, 0, 5])
plt.gca().set_xlabel('Number of dimensions')
plt.gca().set_ylabel('Time taken to cluster (s)')
plt.title('Performance Comparison of Clustering Implementations')
plt.legend()
plt.savefig('large_k_plot.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-c521fb86efae> in <module>()
#       1 plt.figure(figsize=(25,10))
# ----> 2 sns.regplot(x='x', y='y', data=to_df(k_means_dimdata, k_sizes), order=2,
#       3             label='Sklearn K-Means', x_estimator=np.mean)
#       4 sns.regplot(x='x', y='y', data=to_df(dbscan_dimdata, k_sizes), order=2,
#       5             label='Sklearn DBSCAN', x_estimator=np.mean)
#
# NameError: name 'k_means_dimdata' is not defined
